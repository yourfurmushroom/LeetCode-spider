# %%
import requests,json,re
from requests_toolbelt import MultipartEncoder

# %%
session = requests.Session()
user_agent = r'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36'

# %%
def get_problems():
    url = "https://leetcode.com/api/problems/all/"

    headers = {'User-Agent': user_agent, 'Connection': 'keep-alive'}
    resp = session.get(url, headers = headers, timeout = 10)
       
    question_list = json.loads(resp.content.decode('utf-8'))

    allTitle=[]
    for question in question_list['stat_status_pairs']:
        question_id = question['stat']['question_id']
        question_slug = question['stat']['question__title_slug']
        question_status = question['status']
        level = question['difficulty']['level']
        if question['paid_only']:
            continue
        allTitle.append(question_slug)
    return allTitle   

def get_problem_by_slug(slug):
    url = "https://leetcode.com/graphql"
    params = {'operationName': "getQuestionDetail",
        'variables': {'titleSlug': slug},
        'query': '''query getQuestionDetail($titleSlug: String!) {
            question(titleSlug: $titleSlug) {
                questionId
                questionFrontendId
                questionTitle
                questionTitleSlug
                content
                difficulty
                stats
                similarQuestions
                categoryTitle
                topicTags {
                        name
                        slug
                }
            }
        }'''
    }

    json_data = json.dumps(params).encode('utf8')
                        
    headers = {'User-Agent': user_agent, 'Connection': 
        'keep-alive', 'Content-Type': 'application/json',
        'Referer': 'https://leetcode.com/problems/' + slug}
    resp = session.post(url, data = json_data, headers = headers, timeout = 10)
    content = resp.json()

    # 题目详细信息
    # question = content['data']['question']['questionTitleSlug']
    # content=content['data']['question']['content']
    return content['data']['question']['questionFrontendId'],content['data']['question']['content']

# %%
def get_sol_by_slug(slug,start):
    url = f"https://leetcode.com/graphql/{slug}/"
    params = {'operationName': "communitySolutions",
        'variables': {'query': "", 'languageTags': ["cpp"], 'topicTags': [], 'questionSlug': slug, 'skip': start*15,'first':15,'orderBy':'hot'},
        'query': '''query communitySolutions($questionSlug: String!, $skip: Int!, $first: Int!, $query: String, $orderBy: TopicSortingOption, $languageTags: [String!], $topicTags: [String!]) {
            questionSolutions(filters: {questionSlug: $questionSlug, skip: $skip, first: $first, query: $query, orderBy: $orderBy, languageTags: $languageTags, topicTags: $topicTags}) {
                hasDirectResults
                totalNum
                solutions {
                    id
                    title
                    commentCount
                    topLevelCommentCount
                    viewCount
                    pinned
                    isFavorite
                    solutionTags {
                        name
                        slug
                    }    
                }
            }
        }    
        '''
    }
    try:
        json_data = json.dumps(params).encode('utf8')
    except:
        return []
                        
    headers = {'User-Agent': user_agent, 'Connection': 
        'keep-alive', 'Content-Type': 'application/json',
        'Referer': 'https://leetcode.com/problems/' + slug+'/solutions'}
    resp = session.post(url, data = json_data, headers = headers, timeout = 10)
    content = resp.json()
    return content['data']['questionSolutions']['solutions']

# %%
def getSolution(slug,id,t):
    url = f"https://leetcode.com/graphql/{slug}/solution"
    params = {'operationName': "communitySolution",
        'variables': {'topicId': id},
        'query': '''query communitySolution($topicId: Int!) {
            topic(id: $topicId) {
                post {
                    id
                    voteCount
                    voteStatus
                    content
                }
            }
        }   
        '''
    }

    json_data = json.dumps(params).encode('utf8')
                        
    headers = {'User-Agent': user_agent, 'Connection': 
        'keep-alive', 'Content-Type': 'application/json',
        'Referer': 'https://leetcode.com/problems/' + slug+'/solutions/'+str(id)+'/'+t}
    resp = session.post(url, data = json_data, headers = headers, timeout = 10)
    content = resp.json()


    return content['data']['topic']['post']['content']

# %%
import csv
def writecsv(htmlItems,t,title,id,counter,leetcodeDesc):
    # with open(f"test\\{title}_{t}_{id}_{counter}.txt",'w')as f:
    #     for i in htmlItems:
    #         i=i.replace("\\t","")
    #         f.write(i+'\n')
    try:
        with open('outputT.csv', 'a', newline='') as csvfile:
            writer = csv.writer(csvfile)
            writer.writerow([t, leetcodeDesc, htmlItems])
    except:
        return

# %%
def RemoveTag(htmlString):
    pattern = re.compile('<.*?>')
    result = re.sub(pattern, '', htmlString)
    result=result.replace("\n"," ")
    return result

# %%
with open('outputT.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['question', 'context', 'answer'])
titles=get_problems()
for t in titles:
    id,leetcodeDesc=get_problem_by_slug(t)
    leetcodeDesc=RemoveTag(leetcodeDesc)#取t的題目敘述，t是題目標題
    for i in range(7):
        try:
            temp=get_sol_by_slug(t,i)
            for j in iter(temp):
                title=j['title']
                title=re.sub('[^\w]'," ",title).lower()
                title=re.sub('\s+',"-",title)
                if(title[0]=='-'):
                    title=title[1:]
                if(title[-1]=='-'):
                    title=title[:-1]
                print(f"{t}, {j['id']}")
                htmlItems=getSolution(t,j['id'],title)
                counter=1
                while(True):
                    index=htmlItems.find("```")
                    if(index!=-1):
                        index=htmlItems.find("class")
                        if index==-1:
                            index=htmlItems.find("```")
                            htmlItems=htmlItems[index+3:]
                            continue
                        htmlItems=htmlItems[index:]
                        index=htmlItems.find("```")
                        temp=htmlItems[:index]
                        temp=temp.replace("\\n"," ")
                        temp=temp.replace("\n"," ")
                        htmlItems=htmlItems[index+3:]
                        writecsv(temp,id+t,title,j['id'],counter,leetcodeDesc)
                        counter+=1
                    else:
                        break
        except:
            continue
# Out:
# divisible-and-non-divisible-sums-difference, 4144364
# divisible-and-non-divisible-sums-difference, 4144349
# divisible-and-non-divisible-sums-difference, 4145287
# divisible-and-non-divisible-sums-difference, 4144754
# divisible-and-non-divisible-sums-difference, 4145763
# divisible-and-non-divisible-sums-difference, 4146679
# divisible-and-non-divisible-sums-difference, 4144201
# divisible-and-non-divisible-sums-difference, 4144019
# divisible-and-non-divisible-sums-difference, 4144599
# divisible-and-non-divisible-sums-difference, 4144597
# divisible-and-non-divisible-sums-difference, 4144513
# divisible-and-non-divisible-sums-difference, 4144407
# divisible-and-non-divisible-sums-difference, 4143960
# divisible-and-non-divisible-sums-difference, 4143946
# divisible-and-non-divisible-sums-difference, 4143913
# divisible-and-non-divisible-sums-difference, 4147362
# divisible-and-non-divisible-sums-difference, 4153206
# divisible-and-non-divisible-sums-difference, 4150114
# divisible-and-non-divisible-sums-difference, 4149997
# divisible-and-non-divisible-sums-difference, 4149939
# divisible-and-non-divisible-sums-difference, 4149857
# divisible-and-non-divisible-sums-difference, 4149654
# divisible-and-non-divisible-sums-difference, 4149327
# divisible-and-non-divisible-sums-difference, 4148353
# divisible-and-non-divisible-sums-difference, 4147208
# divisible-and-non-divisible-sums-difference, 4146895
# divisible-and-non-divisible-sums-difference, 4146876
# divisible-and-non-divisible-sums-difference, 4146873
# divisible-and-non-divisible-sums-difference, 4146765
# divisible-and-non-divisible-sums-difference, 4146716
# divisible-and-non-divisible-sums-difference, 4146703
# divisible-and-non-divisible-sums-difference, 4146670
# divisible-and-non-divisible-sums-difference, 4146642
# divisible-and-non-divisible-sums-difference, 4146267
# divisible-and-non-divisible-sums-difference, 4146245
# divisible-and-non-divisible-sums-difference, 4145964
# divisible-and-non-divisible-sums-difference, 4145884
# divisible-and-non-divisible-sums-difference, 4145734
# divisible-and-non-divisible-sums-difference, 4145592
# divisible-and-non-divisible-sums-difference, 4145455
# divisible-and-non-divisible-sums-difference, 4145115
# divisible-and-non-divisible-sums-difference, 4145030
# divisible-and-non-divisible-sums-difference, 4144913
# divisible-and-non-divisible-sums-difference, 4144900
# divisible-and-non-divisible-sums-difference, 4144899
# divisible-and-non-divisible-sums-difference, 4144828
# divisible-and-non-divisible-sums-difference, 4144468
# divisible-and-non-divisible-sums-difference, 4144421
# divisible-and-non-divisible-sums-difference, 4144387
# divisible-and-non-divisible-sums-difference, 4144229
# divisible-and-non-divisible-sums-difference, 4144223
# divisible-and-non-divisible-sums-difference, 4144210
# divisible-and-non-divisible-sums-difference, 4144199
# divisible-and-non-divisible-sums-difference, 4144187
# divisible-and-non-divisible-sums-difference, 4144163
# divisible-and-non-divisible-sums-difference, 4144123
# divisible-and-non-divisible-sums-difference, 4144121
# divisible-and-non-divisible-sums-difference, 4144103
# divisible-and-non-divisible-sums-difference, 4144070
# divisible-and-non-divisible-sums-difference, 4144068
# divisible-and-non-divisible-sums-difference, 4144039
# divisible-and-non-divisible-sums-difference, 4144008
# divisible-and-non-divisible-sums-difference, 4144004
# divisible-and-non-divisible-sums-difference, 4143997
# divisible-and-non-divisible-sums-difference, 4143993
# divisible-and-non-divisible-sums-difference, 4143989
# divisible-and-non-divisible-sums-difference, 4143977
# divisible-and-non-divisible-sums-difference, 4143968
# divisible-and-non-divisible-sums-difference, 4143944
# divisible-and-non-divisible-sums-difference, 4143936
# divisible-and-non-divisible-sums-difference, 4143911
# maximum-value-of-an-ordered-triplet-i, 4111942
# maximum-value-of-an-ordered-triplet-i, 4111925
# maximum-value-of-an-ordered-triplet-i, 4117038
# maximum-value-of-an-ordered-triplet-i, 4114140
# maximum-value-of-an-ordered-triplet-i, 4111896
# maximum-value-of-an-ordered-triplet-i, 4112078
# maximum-value-of-an-ordered-triplet-i, 4115381
# maximum-value-of-an-ordered-triplet-i, 4115243
# maximum-value-of-an-ordered-triplet-i, 4138854
# maximum-value-of-an-ordered-triplet-i, 4113753
# maximum-value-of-an-ordered-triplet-i, 4113058
# maximum-value-of-an-ordered-triplet-i, 4113807
# maximum-value-of-an-ordered-triplet-i, 4112678
# maximum-value-of-an-ordered-triplet-i, 4112056
# maximum-value-of-an-ordered-triplet-i, 4115269
# maximum-value-of-an-ordered-triplet-i, 4112024
# maximum-value-of-an-ordered-triplet-i, 4121919
# maximum-value-of-an-ordered-triplet-i, 4152895
# maximum-value-of-an-ordered-triplet-i, 4152752
# maximum-value-of-an-ordered-triplet-i, 4146301
# maximum-value-of-an-ordered-triplet-i, 4145346
# maximum-value-of-an-ordered-triplet-i, 4138293
# maximum-value-of-an-ordered-triplet-i, 4136552
# maximum-value-of-an-ordered-triplet-i, 4133848
# maximum-value-of-an-ordered-triplet-i, 4129188
# maximum-value-of-an-ordered-triplet-i, 4123328
# maximum-value-of-an-ordered-triplet-i, 4120731
# maximum-value-of-an-ordered-triplet-i, 4120059
# maximum-value-of-an-ordered-triplet-i, 4119674
# maximum-value-of-an-ordered-triplet-i, 4118923
# maximum-value-of-an-ordered-triplet-i, 4117935
# maximum-value-of-an-ordered-triplet-i, 4117742
# maximum-value-of-an-ordered-triplet-i, 4117352
# maximum-value-of-an-ordered-triplet-i, 4117257
# maximum-value-of-an-ordered-triplet-i, 4116441
# maximum-value-of-an-ordered-triplet-i, 4115797
# maximum-value-of-an-ordered-triplet-i, 4115432
# maximum-value-of-an-ordered-triplet-i, 4115380
# maximum-value-of-an-ordered-triplet-i, 4113892
# maximum-value-of-an-ordered-triplet-i, 4113718
# maximum-value-of-an-ordered-triplet-i, 4113550
# maximum-value-of-an-ordered-triplet-i, 4113381
# maximum-value-of-an-ordered-triplet-i, 4112894
# maximum-value-of-an-ordered-triplet-i, 4112781
# maximum-value-of-an-ordered-triplet-i, 4112674
# maximum-value-of-an-ordered-triplet-i, 4112606
# maximum-value-of-an-ordered-triplet-i, 4112546
# maximum-value-of-an-ordered-triplet-i, 4112462
# maximum-value-of-an-ordered-triplet-i, 4112374
# maximum-value-of-an-ordered-triplet-i, 4112186
# maximum-value-of-an-ordered-triplet-i, 4112110
# maximum-value-of-an-ordered-triplet-i, 4112101
# maximum-value-of-an-ordered-triplet-i, 4112089
# maximum-value-of-an-ordered-triplet-i, 4112003
# maximum-value-of-an-ordered-triplet-i, 4111993
# maximum-value-of-an-ordered-triplet-i, 4111969
# maximum-value-of-an-ordered-triplet-i, 4111968
# maximum-value-of-an-ordered-triplet-i, 4111901
# maximum-value-of-an-ordered-triplet-i, 4111879
# maximum-value-of-an-ordered-triplet-i, 4111873
# apply-operations-on-array-to-maximize-sum-of-squares, 4144343
# apply-operations-on-array-to-maximize-sum-of-squares, 4144060
# apply-operations-on-array-to-maximize-sum-of-squares, 4144778
# apply-operations-on-array-to-maximize-sum-of-squares, 4144660
# apply-operations-on-array-to-maximize-sum-of-squares, 4143995
# apply-operations-on-array-to-maximize-sum-of-squares, 4147256
# apply-operations-on-array-to-maximize-sum-of-squares, 4144087
# apply-operations-on-array-to-maximize-sum-of-squares, 4144076
# apply-operations-on-array-to-maximize-sum-of-squares, 4149432
# apply-operations-on-array-to-maximize-sum-of-squares, 4149039
# apply-operations-on-array-to-maximize-sum-of-squares, 4148494
# apply-operations-on-array-to-maximize-sum-of-squares, 4147035
# apply-operations-on-array-to-maximize-sum-of-squares, 4145673
# apply-operations-on-array-to-maximize-sum-of-squares, 4145494
# apply-operations-on-array-to-maximize-sum-of-squares, 4145324
# apply-operations-on-array-to-maximize-sum-of-squares, 4145289
# apply-operations-on-array-to-maximize-sum-of-squares, 4145226
# apply-operations-on-array-to-maximize-sum-of-squares, 4144894
# apply-operations-on-array-to-maximize-sum-of-squares, 4144883
# apply-operations-on-array-to-maximize-sum-of-squares, 4144722
# apply-operations-on-array-to-maximize-sum-of-squares, 4144572
# apply-operations-on-array-to-maximize-sum-of-squares, 4144114
# apply-operations-on-array-to-maximize-sum-of-squares, 4144096
# apply-operations-on-array-to-maximize-sum-of-squares, 4144064
# apply-operations-on-array-to-maximize-sum-of-squares, 4144021
# apply-operations-on-array-to-maximize-sum-of-squares, 4143931
# maximum-value-of-an-ordered-triplet-ii, 4115444
# maximum-value-of-an-ordered-triplet-ii, 4115284
# maximum-value-of-an-ordered-triplet-ii, 4111941
# maximum-value-of-an-ordered-triplet-ii, 4111877
# maximum-value-of-an-ordered-triplet-ii, 4111996
# maximum-value-of-an-ordered-triplet-ii, 4111907
# maximum-value-of-an-ordered-triplet-ii, 4115528
# maximum-value-of-an-ordered-triplet-ii, 4117112
# maximum-value-of-an-ordered-triplet-ii, 4115267
# maximum-value-of-an-ordered-triplet-ii, 4114121
# maximum-value-of-an-ordered-triplet-ii, 4111874
# maximum-value-of-an-ordered-triplet-ii, 4112088
# maximum-value-of-an-ordered-triplet-ii, 4113801
# maximum-value-of-an-ordered-triplet-ii, 4113322
# maximum-value-of-an-ordered-triplet-ii, 4113009
# maximum-value-of-an-ordered-triplet-ii, 4112656
# maximum-value-of-an-ordered-triplet-ii, 4117976
# maximum-value-of-an-ordered-triplet-ii, 4115484
# maximum-value-of-an-ordered-triplet-ii, 4112994
# maximum-value-of-an-ordered-triplet-ii, 4112857
# maximum-value-of-an-ordered-triplet-ii, 4112615
# maximum-value-of-an-ordered-triplet-ii, 4112100
# maximum-value-of-an-ordered-triplet-ii, 4112073
# maximum-value-of-an-ordered-triplet-ii, 4112058
# maximum-value-of-an-ordered-triplet-ii, 4111984
# maximum-value-of-an-ordered-triplet-ii, 4111890
# maximum-value-of-an-ordered-triplet-ii, 4112865
# maximum-value-of-an-ordered-triplet-ii, 4113756
# maximum-value-of-an-ordered-triplet-ii, 4111953
# maximum-value-of-an-ordered-triplet-ii, 4112610
# maximum-value-of-an-ordered-triplet-ii, 4149287
# maximum-value-of-an-ordered-triplet-ii, 4146406
# maximum-value-of-an-ordered-triplet-ii, 4146256
# maximum-value-of-an-ordered-triplet-ii, 4143882
# maximum-value-of-an-ordered-triplet-ii, 4140980
# maximum-value-of-an-ordered-triplet-ii, 4136596
# maximum-value-of-an-ordered-triplet-ii, 4134436
# maximum-value-of-an-ordered-triplet-ii, 4133654
# maximum-value-of-an-ordered-triplet-ii, 4130556
# maximum-value-of-an-ordered-triplet-ii, 4129505
# maximum-value-of-an-ordered-triplet-ii, 4128443
# maximum-value-of-an-ordered-triplet-ii, 4126638
# maximum-value-of-an-ordered-triplet-ii, 4126361
# maximum-value-of-an-ordered-triplet-ii, 4124639
# maximum-value-of-an-ordered-triplet-ii, 4124070
# maximum-value-of-an-ordered-triplet-ii, 4123742
# maximum-value-of-an-ordered-triplet-ii, 4123369
# maximum-value-of-an-ordered-triplet-ii, 4121132
# maximum-value-of-an-ordered-triplet-ii, 4120646
# maximum-value-of-an-ordered-triplet-ii, 4120044
# maximum-value-of-an-ordered-triplet-ii, 4119378
# maximum-value-of-an-ordered-triplet-ii, 4119340
# maximum-value-of-an-ordered-triplet-ii, 4118432
# maximum-value-of-an-ordered-triplet-ii, 4118124
# maximum-value-of-an-ordered-triplet-ii, 4117768
# maximum-value-of-an-ordered-triplet-ii, 4117543
# maximum-value-of-an-ordered-triplet-ii, 4117421
# maximum-value-of-an-ordered-triplet-ii, 4117360
# maximum-value-of-an-ordered-triplet-ii, 4116292
# maximum-value-of-an-ordered-triplet-ii, 4116151
# maximum-value-of-an-ordered-triplet-ii, 4116080
# maximum-value-of-an-ordered-triplet-ii, 4115971
# maximum-value-of-an-ordered-triplet-ii, 4115600
# maximum-value-of-an-ordered-triplet-ii, 4115549
# maximum-value-of-an-ordered-triplet-ii, 4115547
# maximum-value-of-an-ordered-triplet-ii, 4115502
# maximum-value-of-an-ordered-triplet-ii, 4115136
# maximum-value-of-an-ordered-triplet-ii, 4115010
# maximum-value-of-an-ordered-triplet-ii, 4114799
# maximum-value-of-an-ordered-triplet-ii, 4114742
# maximum-value-of-an-ordered-triplet-ii, 4114672
# maximum-value-of-an-ordered-triplet-ii, 4114501
# maximum-value-of-an-ordered-triplet-ii, 4114384
# maximum-value-of-an-ordered-triplet-ii, 4114077
# maximum-value-of-an-ordered-triplet-ii, 4113913
# maximum-value-of-an-ordered-triplet-ii, 4113868
# maximum-value-of-an-ordered-triplet-ii, 4113739
# maximum-value-of-an-ordered-triplet-ii, 4113722
# maximum-value-of-an-ordered-triplet-ii, 4113688
# maximum-value-of-an-ordered-triplet-ii, 4113613
# maximum-value-of-an-ordered-triplet-ii, 4113581
# maximum-value-of-an-ordered-triplet-ii, 4113517
# maximum-value-of-an-ordered-triplet-ii, 4113410
# maximum-value-of-an-ordered-triplet-ii, 4113320
# maximum-value-of-an-ordered-triplet-ii, 4113258
# maximum-value-of-an-ordered-triplet-ii, 4113219
# maximum-value-of-an-ordered-triplet-ii, 4112882
# maximum-value-of-an-ordered-triplet-ii, 4112842
# maximum-value-of-an-ordered-triplet-ii, 4112839
# maximum-value-of-an-ordered-triplet-ii, 4112825
# maximum-value-of-an-ordered-triplet-ii, 4112804
# maximum-value-of-an-ordered-triplet-ii, 4112666
# maximum-value-of-an-ordered-triplet-ii, 4112614
# maximum-value-of-an-ordered-triplet-ii, 4112568
# maximum-value-of-an-ordered-triplet-ii, 4112432
# maximum-value-of-an-ordered-triplet-ii, 4112421
# maximum-value-of-an-ordered-triplet-ii, 4112420
# maximum-value-of-an-ordered-triplet-ii, 4112413
# maximum-value-of-an-ordered-triplet-ii, 4112403
# beautiful-towers-i, 4118203
# beautiful-towers-i, 4106982
# beautiful-towers-i, 4106730
# beautiful-towers-i, 4098039
# beautiful-towers-i, 4092288
# beautiful-towers-i, 4089997
# beautiful-towers-i, 4087589
# beautiful-towers-i, 4087406
# beautiful-towers-i, 4087359
# beautiful-towers-i, 4086575
# beautiful-towers-i, 4086221
# beautiful-towers-i, 4085986
# beautiful-towers-i, 4085323
# beautiful-towers-i, 4085109
# beautiful-towers-i, 4085074
# beautiful-towers-i, 4084797
# beautiful-towers-i, 4084666
# beautiful-towers-i, 4084515
# beautiful-towers-i, 4084449
# beautiful-towers-i, 4084087
# beautiful-towers-i, 4084064
# beautiful-towers-i, 4083937
# beautiful-towers-i, 4083848
# beautiful-towers-i, 4083826
# beautiful-towers-i, 4083812
# beautiful-towers-i, 4083810
# beautiful-towers-i, 4083739
# beautiful-towers-i, 4083699
# beautiful-towers-i, 4083627
# beautiful-towers-i, 4083553
# beautiful-towers-i, 4083515
# beautiful-towers-i, 4083438
# beautiful-towers-i, 4083427
# beautiful-towers-i, 4083407
# beautiful-towers-i, 4083252
# beautiful-towers-i, 4083235
# beautiful-towers-i, 4083207
# beautiful-towers-i, 4083109
# beautiful-towers-i, 4083098
# beautiful-towers-i, 4083068
# beautiful-towers-i, 4083045
# beautiful-towers-i, 4083041
# beautiful-towers-i, 4083024
# beautiful-towers-i, 4083003
# beautiful-towers-i, 4082981
# beautiful-towers-i, 4082968
# beautiful-towers-i, 4082928
# beautiful-towers-i, 4082890
# beautiful-towers-i, 4082888
# beautiful-towers-i, 4082887
# beautiful-towers-i, 4082872
# beautiful-towers-i, 4082827
# beautiful-towers-i, 4082821
# beautiful-towers-i, 4082813
# beautiful-towers-i, 4082800
# beautiful-towers-i, 4082786
# beautiful-towers-i, 4082784
# beautiful-towers-i, 4082774
# beautiful-towers-i, 4082764
# beautiful-towers-ii, 4082802
# beautiful-towers-ii, 4118466
# beautiful-towers-ii, 4083280
# beautiful-towers-ii, 4082933
# beautiful-towers-ii, 4083004
# beautiful-towers-ii, 4083981
# beautiful-towers-ii, 4084335
# beautiful-towers-ii, 4082866
# beautiful-towers-ii, 4083693
# beautiful-towers-ii, 4083419
# beautiful-towers-ii, 4083040
# beautiful-towers-ii, 4088106
# beautiful-towers-ii, 4084625
# beautiful-towers-ii, 4084480
# beautiful-towers-ii, 4083414
# beautiful-towers-ii, 4082884
# beautiful-towers-ii, 4082870
# beautiful-towers-ii, 4084063
# beautiful-towers-ii, 4083591
# beautiful-towers-ii, 4083010
# beautiful-towers-ii, 4083135
# beautiful-towers-ii, 4082930
# beautiful-towers-ii, 4085997
# beautiful-towers-ii, 4138347
# beautiful-towers-ii, 4137888
# beautiful-towers-ii, 4133116
# beautiful-towers-ii, 4124773
# beautiful-towers-ii, 4108961
# beautiful-towers-ii, 4106508
# beautiful-towers-ii, 4106334
# beautiful-towers-ii, 4101136
# beautiful-towers-ii, 4099757
# beautiful-towers-ii, 4099619
# beautiful-towers-ii, 4098963
# minimum-number-of-operations-to-make-array-empty, 4113741
# minimum-number-of-operations-to-make-array-empty, 4113477
# minimum-number-of-operations-to-make-array-empty, 4113416
# minimum-number-of-operations-to-make-array-empty, 4112920
# minimum-number-of-operations-to-make-array-empty, 4112775
# minimum-number-of-operations-to-make-array-empty, 4112758
# minimum-number-of-operations-to-make-array-empty, 4112708
# minimum-number-of-operations-to-make-array-empty, 4112593
# minimum-number-of-operations-to-make-array-empty, 4112523
# minimum-number-of-operations-to-make-array-empty, 4112341
# minimum-number-of-operations-to-make-array-empty, 4112254
# minimum-number-of-operations-to-make-array-empty, 4112175
# minimum-number-of-operations-to-make-array-empty, 4111854
# minimum-number-of-operations-to-make-array-empty, 4111572
# minimum-number-of-operations-to-make-array-empty, 4111309
# minimum-number-of-operations-to-make-array-empty, 4111256
# minimum-number-of-operations-to-make-array-empty, 4111228
# minimum-number-of-operations-to-make-array-empty, 4111135
# minimum-number-of-operations-to-make-array-empty, 4111001
# minimum-number-of-operations-to-make-array-empty, 4110956
# minimum-number-of-operations-to-make-array-empty, 4110953
# minimum-number-of-operations-to-make-array-empty, 4110949
# minimum-number-of-operations-to-make-array-empty, 4110937
# minimum-number-of-operations-to-make-array-empty, 4110912
# minimum-number-of-operations-to-make-array-empty, 4110826
# minimum-number-of-operations-to-make-array-empty, 4110809
# minimum-number-of-operations-to-make-array-empty, 4110771
# minimum-number-of-operations-to-make-array-empty, 4110742
# minimum-number-of-operations-to-make-array-empty, 4110712
# minimum-number-of-operations-to-make-array-empty, 4110693
# minimum-number-of-operations-to-make-array-empty, 4110666
# minimum-number-of-operations-to-make-array-empty, 4110639
# minimum-number-of-operations-to-make-array-empty, 4110619
# minimum-number-of-operations-to-make-array-empty, 4110608
# minimum-number-of-operations-to-make-array-empty, 4110605
# minimum-number-of-operations-to-make-array-empty, 4110575
# minimum-number-of-operations-to-make-array-empty, 4110568
# minimum-number-of-operations-to-make-array-empty, 4110512
# minimum-number-of-operations-to-make-array-empty, 4110465
# minimum-number-of-operations-to-make-array-empty, 4110404
# minimum-number-of-operations-to-make-array-empty, 4110402
# minimum-number-of-operations-to-make-array-empty, 4110354
# minimum-number-of-operations-to-make-array-empty, 4110346
# minimum-number-of-operations-to-make-array-empty, 4110326
# minimum-number-of-operations-to-make-array-empty, 4110304
# minimum-number-of-operations-to-make-array-empty, 4110270
# minimum-number-of-operations-to-make-array-empty, 4110243
# minimum-number-of-operations-to-make-array-empty, 4110210
# minimum-number-of-operations-to-make-array-empty, 4110208
# minimum-number-of-operations-to-make-array-empty, 4110181
# minimum-number-of-operations-to-make-array-empty, 4110179
# minimum-number-of-operations-to-make-array-empty, 4110163
# minimum-number-of-operations-to-make-array-empty, 4110162
# minimum-number-of-operations-to-make-array-empty, 4110143
# minimum-number-of-operations-to-make-array-empty, 4110136
# minimum-number-of-operations-to-make-array-empty, 4110131
# minimum-number-of-operations-to-make-array-empty, 4110127
# minimum-number-of-operations-to-make-array-empty, 4110115
# minimum-number-of-operations-to-make-array-empty, 4110109
# minimum-number-of-operations-to-make-array-empty, 4110107
# minimum-number-of-operations-to-make-array-empty, 4110104
# sum-of-values-at-indices-with-k-set-bits, 4057093
# sum-of-values-at-indices-with-k-set-bits, 4056398
# sum-of-values-at-indices-with-k-set-bits, 4055952
# sum-of-values-at-indices-with-k-set-bits, 4055498
# sum-of-values-at-indices-with-k-set-bits, 4053852
# sum-of-values-at-indices-with-k-set-bits, 4074309
# sum-of-values-at-indices-with-k-set-bits, 4067852
# sum-of-values-at-indices-with-k-set-bits, 4054748
# sum-of-values-at-indices-with-k-set-bits, 4053999
# sum-of-values-at-indices-with-k-set-bits, 4053888
# sum-of-values-at-indices-with-k-set-bits, 4053974
# sum-of-values-at-indices-with-k-set-bits, 4053906
# sum-of-values-at-indices-with-k-set-bits, 4088426
# sum-of-values-at-indices-with-k-set-bits, 4054116
# sum-of-values-at-indices-with-k-set-bits, 4078446
# sum-of-values-at-indices-with-k-set-bits, 4054361
# sum-of-values-at-indices-with-k-set-bits, 4059878
# sum-of-values-at-indices-with-k-set-bits, 4056681
# sum-of-values-at-indices-with-k-set-bits, 4150141
# sum-of-values-at-indices-with-k-set-bits, 4142164
# sum-of-values-at-indices-with-k-set-bits, 4140857
# sum-of-values-at-indices-with-k-set-bits, 4134249
# sum-of-values-at-indices-with-k-set-bits, 4133837
# sum-of-values-at-indices-with-k-set-bits, 4133710
# sum-of-values-at-indices-with-k-set-bits, 4121677
# sum-of-values-at-indices-with-k-set-bits, 4121396
# sum-of-values-at-indices-with-k-set-bits, 4120561
# sum-of-values-at-indices-with-k-set-bits, 4116439
# sum-of-values-at-indices-with-k-set-bits, 4111699
# sum-of-values-at-indices-with-k-set-bits, 4106015
# sum-of-values-at-indices-with-k-set-bits, 4096571
# sum-of-values-at-indices-with-k-set-bits, 4094321
# sum-of-values-at-indices-with-k-set-bits, 4093909
# sum-of-values-at-indices-with-k-set-bits, 4091149
# sum-of-values-at-indices-with-k-set-bits, 4090911
# sum-of-values-at-indices-with-k-set-bits, 4089810
# sum-of-values-at-indices-with-k-set-bits, 4087685
# sum-of-values-at-indices-with-k-set-bits, 4087427
# sum-of-values-at-indices-with-k-set-bits, 4084452
# sum-of-values-at-indices-with-k-set-bits, 4083334
# sum-of-values-at-indices-with-k-set-bits, 4082381
# sum-of-values-at-indices-with-k-set-bits, 4082106
# sum-of-values-at-indices-with-k-set-bits, 4079009
# sum-of-values-at-indices-with-k-set-bits, 4077079
# sum-of-values-at-indices-with-k-set-bits, 4076934
# sum-of-values-at-indices-with-k-set-bits, 4072877
# sum-of-values-at-indices-with-k-set-bits, 4070097
# sum-of-values-at-indices-with-k-set-bits, 4067253
# sum-of-values-at-indices-with-k-set-bits, 4066643
# sum-of-values-at-indices-with-k-set-bits, 4065692
# sum-of-values-at-indices-with-k-set-bits, 4065353
# sum-of-values-at-indices-with-k-set-bits, 4063644
# sum-of-values-at-indices-with-k-set-bits, 4063589
# sum-of-values-at-indices-with-k-set-bits, 4060402
# sum-of-values-at-indices-with-k-set-bits, 4059182
# sum-of-values-at-indices-with-k-set-bits, 4058987
# sum-of-values-at-indices-with-k-set-bits, 4058293
# sum-of-values-at-indices-with-k-set-bits, 4058152
# sum-of-values-at-indices-with-k-set-bits, 4057289
# sum-of-values-at-indices-with-k-set-bits, 4057163
# sum-of-values-at-indices-with-k-set-bits, 4057036
# sum-of-values-at-indices-with-k-set-bits, 4056919
# sum-of-values-at-indices-with-k-set-bits, 4056627
# sum-of-values-at-indices-with-k-set-bits, 4056478
# sum-of-values-at-indices-with-k-set-bits, 4056374
# sum-of-values-at-indices-with-k-set-bits, 4056182
# sum-of-values-at-indices-with-k-set-bits, 4055684
# sum-of-values-at-indices-with-k-set-bits, 4055025
# sum-of-values-at-indices-with-k-set-bits, 4055021
# sum-of-values-at-indices-with-k-set-bits, 4054919
# sum-of-values-at-indices-with-k-set-bits, 4054850
# sum-of-values-at-indices-with-k-set-bits, 4054759
# sum-of-values-at-indices-with-k-set-bits, 4054756
# sum-of-values-at-indices-with-k-set-bits, 4054744
# sum-of-values-at-indices-with-k-set-bits, 4054733
# sum-of-values-at-indices-with-k-set-bits, 4054691
# sum-of-values-at-indices-with-k-set-bits, 4054654
# sum-of-values-at-indices-with-k-set-bits, 4054627
# sum-of-values-at-indices-with-k-set-bits, 4054626
# sum-of-values-at-indices-with-k-set-bits, 4054538
# sum-of-values-at-indices-with-k-set-bits, 4054462
# sum-of-values-at-indices-with-k-set-bits, 4054326
# sum-of-values-at-indices-with-k-set-bits, 4054283
# sum-of-values-at-indices-with-k-set-bits, 4054198
# sum-of-values-at-indices-with-k-set-bits, 4054156
# ...
# maximum-element-sum-of-a-complete-subset-of-indices, 4054320
# maximum-element-sum-of-a-complete-subset-of-indices, 4054235
# maximum-element-sum-of-a-complete-subset-of-indices, 4054179
# maximum-element-sum-of-a-complete-subset-of-indices, 4054097
# maximum-element-sum-of-a-complete-subset-of-indices, 4054066
# maximum-element-sum-of-a-complete-subset-of-indices, 4054018
# maximum-element-sum-of-a-complete-subset-of-indices, 4053894
# minimum-operations-to-make-a-special-number, 3994916
# minimum-operations-to-make-a-special-number, 3994894
# minimum-operations-to-make-a-special-number, 3998151
# minimum-operations-to-make-a-special-number, 3994993
# minimum-operations-to-make-a-special-number, 3997460
# minimum-operations-to-make-a-special-number, 3994871
# minimum-operations-to-make-a-special-number, 3995857
# minimum-operations-to-make-a-special-number, 3995081
# minimum-operations-to-make-a-special-number, 4001307
# minimum-operations-to-make-a-special-number, 3995817
# minimum-operations-to-make-a-special-number, 3995310
# minimum-operations-to-make-a-special-number, 3995288
# minimum-operations-to-make-a-special-number, 3995095
# minimum-operations-to-make-a-special-number, 3995082
# minimum-operations-to-make-a-special-number, 3995076
# minimum-operations-to-make-a-special-number, 3995011
# minimum-operations-to-make-a-special-number, 3994865
# minimum-operations-to-make-a-special-number, 3997709
# minimum-operations-to-make-a-special-number, 3995415
# minimum-operations-to-make-a-special-number, 3999492
# minimum-operations-to-make-a-special-number, 3995566
# minimum-operations-to-make-a-special-number, 3996673
# minimum-operations-to-make-a-special-number, 3996602
# minimum-operations-to-make-a-special-number, 3996586
# minimum-operations-to-make-a-special-number, 3996514
# minimum-operations-to-make-a-special-number, 3996505
# minimum-operations-to-make-a-special-number, 3996417
# minimum-operations-to-make-a-special-number, 3996329
# minimum-operations-to-make-a-special-number, 3996238
# minimum-operations-to-make-a-special-number, 3996237
# minimum-operations-to-make-a-special-number, 3996155
# minimum-operations-to-make-a-special-number, 3996102
# minimum-operations-to-make-a-special-number, 3996024
# minimum-operations-to-make-a-special-number, 3995999
# minimum-operations-to-make-a-special-number, 3995990
# minimum-operations-to-make-a-special-number, 3995951
# minimum-operations-to-make-a-special-number, 3995939
# minimum-operations-to-make-a-special-number, 3995915
# minimum-operations-to-make-a-special-number, 3995882
# minimum-right-shifts-to-sort-the-array, 4052116
# minimum-right-shifts-to-sort-the-array, 4052199
# minimum-right-shifts-to-sort-the-array, 4052149
# minimum-right-shifts-to-sort-the-array, 4052090
# minimum-right-shifts-to-sort-the-array, 4139727
# minimum-right-shifts-to-sort-the-array, 4090815
# minimum-right-shifts-to-sort-the-array, 4056607
# minimum-right-shifts-to-sort-the-array, 4052439
# minimum-right-shifts-to-sort-the-array, 4052244
# minimum-right-shifts-to-sort-the-array, 4052180
# minimum-right-shifts-to-sort-the-array, 4073281
# minimum-right-shifts-to-sort-the-array, 4052467
# minimum-right-shifts-to-sort-the-array, 4052133
# minimum-right-shifts-to-sort-the-array, 4053193
# minimum-right-shifts-to-sort-the-array, 4053001
# minimum-right-shifts-to-sort-the-array, 4052267
# minimum-right-shifts-to-sort-the-array, 4058158
# minimum-right-shifts-to-sort-the-array, 4053013
# minimum-right-shifts-to-sort-the-array, 4052238
# minimum-right-shifts-to-sort-the-array, 4142096
# minimum-right-shifts-to-sort-the-array, 4118189
# minimum-right-shifts-to-sort-the-array, 4100285
# minimum-right-shifts-to-sort-the-array, 4098438
# minimum-right-shifts-to-sort-the-array, 4088211
# minimum-right-shifts-to-sort-the-array, 4088151
# minimum-right-shifts-to-sort-the-array, 4084201
# minimum-right-shifts-to-sort-the-array, 4083921
# minimum-right-shifts-to-sort-the-array, 4082576
# minimum-right-shifts-to-sort-the-array, 4080378
# minimum-right-shifts-to-sort-the-array, 4079766
# minimum-right-shifts-to-sort-the-array, 4078997
# minimum-right-shifts-to-sort-the-array, 4075667
# minimum-right-shifts-to-sort-the-array, 4075122
# minimum-right-shifts-to-sort-the-array, 4072945
# minimum-right-shifts-to-sort-the-array, 4072715
# minimum-right-shifts-to-sort-the-array, 4069754
# minimum-right-shifts-to-sort-the-array, 4068895
# minimum-right-shifts-to-sort-the-array, 4067576
# minimum-right-shifts-to-sort-the-array, 4064405
# minimum-right-shifts-to-sort-the-array, 4062616
# minimum-right-shifts-to-sort-the-array, 4061628
# minimum-right-shifts-to-sort-the-array, 4059783
# minimum-right-shifts-to-sort-the-array, 4059132
# minimum-right-shifts-to-sort-the-array, 4058714
# minimum-right-shifts-to-sort-the-array, 4056650
# minimum-right-shifts-to-sort-the-array, 4056646
# minimum-right-shifts-to-sort-the-array, 4056444
# minimum-right-shifts-to-sort-the-array, 4056373
# minimum-right-shifts-to-sort-the-array, 4055769
# minimum-right-shifts-to-sort-the-array, 4055316
# minimum-right-shifts-to-sort-the-array, 4055153
# minimum-right-shifts-to-sort-the-array, 4055136
# minimum-right-shifts-to-sort-the-array, 4055134
# minimum-right-shifts-to-sort-the-array, 4054847
# minimum-right-shifts-to-sort-the-array, 4054794
# minimum-right-shifts-to-sort-the-array, 4054753
# minimum-right-shifts-to-sort-the-array, 4054671
# minimum-right-shifts-to-sort-the-array, 4054647
# minimum-right-shifts-to-sort-the-array, 4054638
# minimum-right-shifts-to-sort-the-array, 4054603
# minimum-right-shifts-to-sort-the-array, 4054584
# minimum-right-shifts-to-sort-the-array, 4054553
# minimum-right-shifts-to-sort-the-array, 4054505
# minimum-right-shifts-to-sort-the-array, 4054429
# minimum-right-shifts-to-sort-the-array, 4054381
# minimum-right-shifts-to-sort-the-array, 4054366
# minimum-right-shifts-to-sort-the-array, 4054221
# minimum-right-shifts-to-sort-the-array, 4053841
# minimum-right-shifts-to-sort-the-array, 4053831
# minimum-right-shifts-to-sort-the-array, 4053660
# minimum-right-shifts-to-sort-the-array, 4053502
# minimum-right-shifts-to-sort-the-array, 4053472
# minimum-right-shifts-to-sort-the-array, 4053412
# minimum-right-shifts-to-sort-the-array, 4053321
# minimum-right-shifts-to-sort-the-array, 4053277
# minimum-right-shifts-to-sort-the-array, 4053164
# minimum-right-shifts-to-sort-the-array, 4053074
# minimum-right-shifts-to-sort-the-array, 4052932
# minimum-right-shifts-to-sort-the-array, 4052912
# minimum-right-shifts-to-sort-the-array, 4052904
# minimum-right-shifts-to-sort-the-array, 4052803
# minimum-right-shifts-to-sort-the-array, 4052779
# minimum-right-shifts-to-sort-the-array, 4052743
# minimum-right-shifts-to-sort-the-array, 4052673
# minimum-right-shifts-to-sort-the-array, 4052672
# minimum-right-shifts-to-sort-the-array, 4052661
# minimum-right-shifts-to-sort-the-array, 4052614
# minimum-right-shifts-to-sort-the-array, 4052605
# minimum-right-shifts-to-sort-the-array, 4052591
# minimum-right-shifts-to-sort-the-array, 4052583
# minimum-right-shifts-to-sort-the-array, 4052536
# minimum-right-shifts-to-sort-the-array, 4052525
# minimum-right-shifts-to-sort-the-array, 4052523
# minimum-right-shifts-to-sort-the-array, 4052522
# minimum-right-shifts-to-sort-the-array, 4052512
# minimum-right-shifts-to-sort-the-array, 4052456
# minimum-right-shifts-to-sort-the-array, 4052452
# minimum-right-shifts-to-sort-the-array, 4052450
# minimum-right-shifts-to-sort-the-array, 4052377
# minimum-right-shifts-to-sort-the-array, 4052370
# minimum-right-shifts-to-sort-the-array, 4052327
# minimum-right-shifts-to-sort-the-array, 4052325
# minimum-right-shifts-to-sort-the-array, 4052296
# minimum-right-shifts-to-sort-the-array, 4052263
# minimum-right-shifts-to-sort-the-array, 4052258
# minimum-operations-to-collect-elements, 4110720
# minimum-operations-to-collect-elements, 4110028
# minimum-operations-to-collect-elements, 4110344
# minimum-operations-to-collect-elements, 4110003
# minimum-operations-to-collect-elements, 4109968
# minimum-operations-to-collect-elements, 4110251
# minimum-operations-to-collect-elements, 4115202
# minimum-operations-to-collect-elements, 4110064
# minimum-operations-to-collect-elements, 4111094
# minimum-operations-to-collect-elements, 4113941
# minimum-operations-to-collect-elements, 4110460
# minimum-operations-to-collect-elements, 4147671
# minimum-operations-to-collect-elements, 4145705
# minimum-operations-to-collect-elements, 4142985
# minimum-operations-to-collect-elements, 4142800
# minimum-operations-to-collect-elements, 4139258
# minimum-operations-to-collect-elements, 4134496
# minimum-operations-to-collect-elements, 4130074
# minimum-operations-to-collect-elements, 4128735
# minimum-operations-to-collect-elements, 4127156
# minimum-operations-to-collect-elements, 4124550
# minimum-operations-to-collect-elements, 4123401
# minimum-operations-to-collect-elements, 4119997
# minimum-operations-to-collect-elements, 4119160
# minimum-operations-to-collect-elements, 4118638
# minimum-operations-to-collect-elements, 4118583
# minimum-operations-to-collect-elements, 4117124
# minimum-operations-to-collect-elements, 4116483
# minimum-operations-to-collect-elements, 4115597
# minimum-operations-to-collect-elements, 4115383
# minimum-operations-to-collect-elements, 4115289
# minimum-operations-to-collect-elements, 4114929
# minimum-operations-to-collect-elements, 4114790
# minimum-operations-to-collect-elements, 4114690
# minimum-operations-to-collect-elements, 4114661
# minimum-operations-to-collect-elements, 4113905
# minimum-operations-to-collect-elements, 4113830
# minimum-operations-to-collect-elements, 4113816
# minimum-operations-to-collect-elements, 4113765
# minimum-operations-to-collect-elements, 4113349
# minimum-operations-to-collect-elements, 4112757
# minimum-operations-to-collect-elements, 4112655
# minimum-operations-to-collect-elements, 4112609
# minimum-operations-to-collect-elements, 4112562
# minimum-operations-to-collect-elements, 4112539
# minimum-operations-to-collect-elements, 4112368
# minimum-operations-to-collect-elements, 4111693
# minimum-operations-to-collect-elements, 4110524
# minimum-operations-to-collect-elements, 4110513
# minimum-operations-to-collect-elements, 4110509
# minimum-operations-to-collect-elements, 4110502
# minimum-operations-to-collect-elements, 4110481
# minimum-operations-to-collect-elements, 4110448
# minimum-operations-to-collect-elements, 4110373
# minimum-operations-to-collect-elements, 4110355
# minimum-operations-to-collect-elements, 4110352
# minimum-operations-to-collect-elements, 4110308
# minimum-operations-to-collect-elements, 4110282
# minimum-operations-to-collect-elements, 4110262
# minimum-operations-to-collect-elements, 4110246
# minimum-operations-to-collect-elements, 4110238
# minimum-operations-to-collect-elements, 4110202
# minimum-operations-to-collect-elements, 4110197
# minimum-operations-to-collect-elements, 4110166
# minimum-operations-to-collect-elements, 4110157
# minimum-operations-to-collect-elements, 4110155
# minimum-operations-to-collect-elements, 4110148
# minimum-operations-to-collect-elements, 4110146
# minimum-operations-to-collect-elements, 4110141
# minimum-operations-to-collect-elements, 4110103
# minimum-operations-to-collect-elements, 4110090
# minimum-operations-to-collect-elements, 4110083
# minimum-operations-to-collect-elements, 4110072
# minimum-operations-to-collect-elements, 4110071
# minimum-operations-to-collect-elements, 4110057
# minimum-operations-to-collect-elements, 4110042
# minimum-operations-to-collect-elements, 4110040
# minimum-operations-to-collect-elements, 4110013
# minimum-operations-to-collect-elements, 4110012
# minimum-operations-to-collect-elements, 4110000
# minimum-operations-to-collect-elements, 4109996
# minimum-operations-to-collect-elements, 4109989
# minimum-operations-to-collect-elements, 4109984
# points-that-intersect-with-cars, 4049693
# points-that-intersect-with-cars, 4074462
# points-that-intersect-with-cars, 4026454
# points-that-intersect-with-cars, 4038536
# points-that-intersect-with-cars, 4025275
# points-that-intersect-with-cars, 4025028
# points-that-intersect-with-cars, 4024943
# points-that-intersect-with-cars, 4024895
# points-that-intersect-with-cars, 4024819
# points-that-intersect-with-cars, 4024789
# points-that-intersect-with-cars, 4024757
# points-that-intersect-with-cars, 4024847
# points-that-intersect-with-cars, 4024738
# points-that-intersect-with-cars, 4025404
# points-that-intersect-with-cars, 4025168
# points-that-intersect-with-cars, 4027468
# points-that-intersect-with-cars, 4026133
# points-that-intersect-with-cars, 4024781
# points-that-intersect-with-cars, 4024930
# points-that-intersect-with-cars, 4026005
# points-that-intersect-with-cars, 4024628
# points-that-intersect-with-cars, 4134965
# points-that-intersect-with-cars, 4128005

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
df=pd.read_csv("output.csv")
df.head()
df_train,df_test=train_test_split(df,test_size=0.3)


df_train.to_json("mydata_train.jsonl", orient='records', lines=True)
df_test.to_json("mydata_eval.jsonl", orient='records', lines=True)

# %%
print(df_train)
# Out:
#                                                 question  \
# 2199               minimize-the-total-price-of-the-trips
# 11511                                       car-fleet-ii
# 17973                number-of-visible-people-in-a-queue
# 30794                              contains-duplicate-ii
# 1820                find-the-losers-of-the-circular-game
# ...                                                  ...
# 15744    number-of-times-binary-string-is-prefix-aligned
# 12537                                      stone-game-vi
# 30833                                 contains-duplicate
# 34319                                   integer-to-roman
# 17704  longest-arithmetic-subsequence-of-given-differ...
#
#                                                  context  \
# 2199   <p>There exists an undirected and unrooted tre...
# 11511  <p>There are <code>n</code> cars traveling at ...
# 17973  <p>There are <code>n</code> people standing in...
# 30794  <p>Given an integer array <code>nums</code> an...
# 1820   <p>There are <code>n</code> friends that are p...
# ...                                                  ...
# 15744  <p>You have a <strong>1-indexed</strong> binar...
# 12537  <p>Alice and Bob take turns playing a game, wi...
# 30833  <p>Given an integer array <code>nums</code>, r...
# 34319  <p>Roman numerals are represented by seven dif...
# 17704  <p>Given an integer array <code>arr</code> and...
#
#                                                   answer
# 2199   class Solution { public:     int count[100];  ...
# 11511  class Solution { public:     vector<double> ge...
# 17973  class Solution { public:     vector<int> canSe...
# 30794  class Solution { public:     bool containsNear...
# 1820   class Solution { public:     vector<int> circu...
# ...                                                  ...
# 15744  class Solution { public:     int numTimesAllBl...
# 12537  class Solution { public:     int stoneGameVI(v...
# 30833  class Solution {     public boolean containsDu...
# 34319  class Solution { public:     string convertInt...
# 17704  class Solution { public:     int helper(int id...
#
# [24299 rows x 3 columns]
